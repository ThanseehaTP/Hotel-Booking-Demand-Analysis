# %% [markdown]
# <div style="
#     background: linear-gradient(135deg, #d9f3ff, #b2dfdb);
#     border: 4px solid #008080;
#     border-radius: 20px;
#     padding: 25px;
#     margin: 20px 0;
#     box-shadow: 0px 6px 15px rgba(0,0,0,0.2);
#     display: flex;
#     justify-content: space-between;
#     align-items: center;
# ">
#
# <div style="flex: 4;">
# <h1 style="
#     color: #00695c;
#     font-family: Tahoma, sans-serif;
#     font-size: 42px;
#     font-weight: bold;
#     text-align: center;
#     text-decoration: underline;
#     margin: 0;
#     letter-spacing: 2px;
# ">
#     CUSTOMER BOOKING BEHAVIOR AND <br>
#     CANCELLATION ANALYSIS IN HOTEL
# </h1>
# <h3 style="
#     text-align:center;
#     color:#004d40;
#     font-family:Georgia;
#     font-style:italic;
#     margin-top:10px;">
#     An Exploratory Data Analysis of Customer Reservations, Booking Patterns, and Cancellation Trends.
# </h3>
# </div>
#
# <div style="flex: 1; text-align: right;">
#     <img src="https://cdn-icons-png.flaticon.com/512/235/235889.png"
#          width="120">
# </div>
#
# </div>

# %% [markdown]
# <div style="
#     background: linear-gradient(135deg, #d9f3ff, #b2dfdb);
#     border: 4px solid #008080;
#     border-radius: 10px;
#     padding:5px;
#     margin: 15px 0;
#     box-shadow: 0px 6px 15px rgba(0,0,0,0.2);
#     display: flex;
#     justify-content: space-between;
#     align-items: center;
# ">
#
# <div style="flex: 4;">
# <h2 style="color:darkblue; font-family:Georgia; font-weight:bold;text-decoration: underline">
# 1.AIM
# </h2>

# %% [markdown]
# To analyze hotel booking patterns, customer behavior, and cancellation trends using exploratory data analysis and visualization.

# %% [markdown]
# <div style="
#     background: linear-gradient(135deg, #d9f3ff, #b2dfdb);
#     border: 4px solid #008080;
#     border-radius: 10px;
#     padding: 5px;
#     margin: 15px 0;
#     box-shadow: 0px 6px 15px rgba(0,0,0,0.2);
#     display: flex;
#     justify-content: space-between;
#     align-items: center;
# ">
#
# <div style="flex: 4;"><h2 style="color:darkblue; font-family:Georgia; font-weight:bold;text-decoration: underline">
# 2.INTRODUCTION
# </h2>

# %% [markdown]
# The hotel industry generates large volumes of booking data that can provide valuable insights into customer behavior and reservation patterns. Analyzing hotel booking records helps identify factors influencing cancellations, booking demand, customer preferences, and revenue generation. This project uses exploratory data analysis and visualization techniques to uncover meaningful trends and support data-driven decision-making in hotel management.

# %% [markdown]
# <div style="
#     background: linear-gradient(135deg, #d9f3ff, #b2dfdb);
#     border: 4px solid #008080;
#     border-radius: 10px;
#     padding: 5px;
#     margin: 15px 0;
#     box-shadow: 0px 6px 15px rgba(0,0,0,0.2);
#     display: flex;
#     justify-content: space-between;
#     align-items: center;
# ">
#
# <div style="flex: 4;">
#     <h2 style="color:darkblue; font-family:Georgia; font-weight:bold;text-decoration: underline">
# 3.PROJECT DESCRIPTION
# </h2>

# %% [markdown]
# This project focuses on analyzing a hotel booking dataset containing information about reservations, customer demographics, booking channels, room assignments, cancellations, and pricing. The analysis aims to discover patterns in customer behavior, identify factors affecting booking cancellations, and evaluate trends related to hotel demand and revenue. Various data visualization and statistical techniques will be used to transform raw booking data into actionable insights.

# %% [markdown]
# <div style="
#     background: linear-gradient(135deg, #d9f3ff, #b2dfdb);
#     border: 4px solid #008080;
#     border-radius: 10px;
#     padding: 5px;
#     margin: 15px 0;
#     box-shadow: 0px 6px 15px rgba(0,0,0,0.2);
#     display: flex;
#     justify-content: space-between;
#     align-items: center;
# ">
#
# <div style="flex: 4;">
#     <h2 style="color:darkblue; font-family:Georgia; font-weight:bold;text-decoration: underline">
# 4.OBJECTIVES
# </h2>

# %% [markdown]
# 1.To analyze hotel booking patterns and customer reservation behavior.
#
# 2.To identify the key factors influencing booking cancellations, such as lead time, deposit type, and customer type.
#
# 3.To examine seasonal and monthly trends in hotel bookings using arrival date information.
#
# 4.To evaluate the impact of market segments and distribution channels on hotel reservations.
#
# 5.To explore customer preferences and booking characteristics through room types, special requests, and length of stay analysis.
#
# 6.To identify trends and relationships among different booking-related variables using data visualization techniques in python.

# %% [markdown]
# <div style="
#     background: linear-gradient(135deg, #d9f3ff, #b2dfdb);
#     border: 4px solid #008080;
#     border-radius: 10px;
#     padding: 5px;
#     margin: 15px 0;
#     box-shadow: 0px 6px 15px rgba(0,0,0,0.2);
#     display: flex;
#     justify-content: space-between;
#     align-items: center;
# ">
#
# <div style="flex: 4;">
#     <h2 style="color:darkblue; font-family:Georgia; font-weight:bold;text-decoration: underline">
# 5.IMPORTING REQUIRED LIBRARIES
# </h2>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# %matplotlib inline
import plotly.express as px 

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# <div style="
#     background: linear-gradient(135deg, #d9f3ff, #b2dfdb);
#     border: 4px solid #008080;
#     border-radius: 10px;
#     padding: 5px;
#     margin: 15px 0;
#     box-shadow: 0px 6px 15px rgba(0,0,0,0.2);
#     display: flex;
#     justify-content: space-between;
#     align-items: center;
# ">
#
# <div style="flex: 4;">
#     <h2 style="color:darkblue; font-family:Georgia; font-weight:bold;text-decoration: underline">
# 6.LOADING THE DATASET
# </h2>

# %%
df=pd.read_csv(r"D:\MAIN PROJECT\HOTEL-BOOKINGS.txt")
df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %% [markdown]
# <h3 style="color:darkblue; font-family:Georgia;text-decoration: underline;font-weight:bold"> COLUMN DESCRIPTION </h3>

# %% [markdown]
# <table style="width:100%; border-collapse:collapse; font-family:Calibri;">
# <tr style="background:linear-gradient(to right, #81d4fa, #80cbc4);">
#     <th style="border:1px solid black; padding:8px;">Variable</th>
#     <th style="border:1px solid black; padding:8px;">Description</th>
# </tr>
#
# <tr><td>hotel</td><td>Type of hotel (Resort Hotel or City Hotel)</td></tr>
# <tr><td>is_canceled</td><td>Booking canceled (1) or not canceled (0)</td></tr>
# <tr><td>lead_time</td><td>Days between booking date and arrival date</td></tr>
# <tr><td>arrival_date_year</td><td>Year of arrival</td></tr>
# <tr><td>arrival_date_month</td><td>Month of arrival</td></tr>
# <tr><td>arrival_date_week_number</td><td>Week number of arrival</td></tr>
# <tr><td>arrival_date_day_of_month</td><td>Day of arrival</td></tr>
# <tr><td>stays_in_weekend_nights</td><td>Number of weekend nights stayed/booked</td></tr>
# <tr><td>stays_in_week_nights</td><td>Number of weekday nights stayed/booked</td></tr>
# <tr><td>adults</td><td>Number of adults</td></tr>
# <tr><td>children</td><td>Number of children</td></tr>
# <tr><td>babies</td><td>Number of babies</td></tr>
# <tr><td>meal</td><td>Type of meal booked. Categories are presented in standard hospitality meal packages: <br> Undefined/SC – no meal package;<br>BB – Bed & Breakfast; <br> HB – Half board (breakfast and one other meal – usually dinner); <br> FB – Full board (breakfast, lunch and dinner)</td></tr>
# <tr><td>country</td><td>Country of origin of guest</td></tr>
# <tr><td>market_segment</td><td>Market segment designation. In categories, the term "TA" means "Travel Agents" and "TO" means "Tour Operators"</td></tr>
# <tr><td>distribution_channel</td><td>Booking distribution channel</td></tr>
# <tr><td>is_repeated_guest</td><td>Whether the guest is a repeat customer</td></tr>
# <tr><td>previous_cancellations</td><td>Number of previous cancellations</td></tr>
# <tr><td>previous_bookings_not_canceled</td><td>Previous bookings not canceled</td></tr>
# <tr><td>reserved_room_type</td><td>Reserved room type code</td></tr>
# <tr><td>assigned_room_type</td><td>Assigned room type code</td></tr>
# <tr><td>booking_changes</td><td>Number of booking modifications</td></tr>
# <tr><td>deposit_type</td><td>Type of deposit made for booking</td></tr>
# <tr><td>agent</td><td>Travel agency ID responsible for booking</td></tr>
# <tr><td>company</td><td>Company ID responsible for payment</td></tr>
# <tr><td>days_in_waiting_list</td><td>Days spent on waiting list</td></tr>
# <tr><td>customer_type</td><td>Type of booking, assuming one of four categories:<br>Contract - when the booking has an allotment or other type of contract associated to it;<br>Group – when the booking is associated to a group;<br>Transient – when the booking is not part of a group or contract, and is not associated to other transient booking;<br>Transient-party – when the booking is transient, but is associated to at least other transient booking</td></tr>
# <tr><td>adr</td><td>Average Daily Rate as defined by dividing the sum of all lodging transactions by the total number of staying nights</td></tr>
# <tr><td>required_car_parking_spaces</td><td>Required parking spaces</td></tr>
# <tr><td>total_of_special_requests</td><td>Total special requests made by customer</td></tr>
# <tr><td>reservation_status</td><td>Latest reservation status</td></tr>
# <tr><td>reservation_status_date</td><td>Date when last reservation status was recorded</td></tr>
#
# </table>

# %% [markdown]
# <div style="
#     background: linear-gradient(135deg, #d9f3ff, #b2dfdb);
#     border: 4px solid #008080;
#     border-radius: 10px;
#     padding: 5px;
#     margin: 15px 0;
#     box-shadow: 0px 6px 15px rgba(0,0,0,0.2);
#     display: flex;
#     justify-content: space-between;
#     align-items: center;
# ">
#
# <div style="flex: 4;">
#     <h2 style="color:darkblue; font-family:Georgia; font-weight:bold;text-decoration: underline">
# 7.DATASET OVERVIEW
# </h2>

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)

# %% [markdown]
# <h3 style="color:darkblue; font-family:Georgia;text-decoration: underline;font-weight:bold"> 👀 FIRST FIVE RECORDS </h3>

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  children  babies  \
# 0                        0                     0       2       0.0       0
# ...

# %% [markdown]
# <h3 style="color:darkblue; font-family:Georgia;text-decoration: underline;font-weight:bold"> 📏 DATASET SHAPE</h3>

# %%
df.shape
# Out:
# (119390, 32)

# %% [markdown]
# <h3 style="color:darkblue; font-family:Georgia;text-decoration: underline;font-weight:bold">🏷️ COLUMN NAMES</h3>

# %%
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %% [markdown]
# <h3 style="color:darkblue; font-family:Georgia;text-decoration: underline;font-weight:bold"> 📝 DATA TYPES & NON-NULL VALUES </h3>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %% [markdown]
# <h3 style="color:darkblue; font-family:Georgia;text-decoration: underline;font-weight:bold">📊 STATISTICAL SUMMARY</h3>

# %%
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %% [markdown]
# <h3 style="color:darkblue; font-family:Georgia;text-decoration: underline;font-weight:bold">🔍 DUPLICATE RECORDS OVERVIEW</h3>

# %%
df.duplicated().sum()
# Out:
# np.int64(31994)

# %% [markdown]
# <h3 style="color:darkblue; font-family:Georgia;text-decoration: underline;font-weight:bold">❓MISSING VALUE ANALYSIS</h3>

# %%
df.isnull().sum()[df.isnull().sum() > 0]
# Out:
# children         4
# country        488
# agent        16340
# company     112593
# dtype: int64

# %% [markdown]
# <div style="
#     background: linear-gradient(135deg, #d9f3ff, #b2dfdb);
#     border: 4px solid #008080;
#     border-radius: 10px;
#     padding: 5px;
#     margin: 15px 0;
#     box-shadow: 0px 6px 15px rgba(0,0,0,0.2);
#     display: flex;
#     justify-content: space-between;
#     align-items: center;
# ">
#
# <div style="flex: 4;">
#     <h2 style="color:darkblue; font-family:Georgia; font-weight:bold;text-decoration: underline">
# 8.DATA CLEANING AND PRE-PROCESSING
# </h2>

# %%
df.columns = df.columns.str.upper()

# %% [markdown]
# <h3 style="color:darkblue; font-family:Georgia;text-decoration: underline;font-weight:bold">⚙️ HANDLING MISSING VALUES</h3>

# %%
df['COUNTRY'] = df['COUNTRY'].fillna('Not provided')

# %%
df['CHILDREN'] = df['CHILDREN'].fillna('0')

# %%
df['AGENT'] = df['AGENT'].fillna('No agent')

# %%
df['COMPANY'] = df['COMPANY'].fillna('No company')

# %%
#checking 
df.isnull().sum()
# Out:
# HOTEL                             0
# IS_CANCELED                       0
# LEAD_TIME                         0
# ARRIVAL_DATE_YEAR                 0
# ARRIVAL_DATE_MONTH                0
# ARRIVAL_DATE_WEEK_NUMBER          0
# ARRIVAL_DATE_DAY_OF_MONTH         0
# STAYS_IN_WEEKEND_NIGHTS           0
# STAYS_IN_WEEK_NIGHTS              0
# ADULTS                            0
# CHILDREN                          0
# BABIES                            0
# MEAL                              0
# COUNTRY                           0
# MARKET_SEGMENT                    0
# DISTRIBUTION_CHANNEL              0
# IS_REPEATED_GUEST                 0
# PREVIOUS_CANCELLATIONS            0
# PREVIOUS_BOOKINGS_NOT_CANCELED    0
# RESERVED_ROOM_TYPE                0
# ASSIGNED_ROOM_TYPE                0
# BOOKING_CHANGES                   0
# DEPOSIT_TYPE                      0
# AGENT                             0
# COMPANY                           0
# DAYS_IN_WAITING_LIST              0
# ...

# %% [markdown]
# <h3 style="color:darkblue; font-family:Georgia;text-decoration: underline;font-weight:bold"> 🔍 DUPLICATE RECORDS HANDLING </h3>

# %%
df=df.drop_duplicates()

# %%
#checking
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (87396, 32)

# %% [markdown]
# <h3 style="color:darkblue; font-family:Georgia;text-decoration: underline;font-weight:bold">📝 DATA REPLACEMENT</h3>

# %%
df = df.copy()
df['IS_CANCELED'] = df['IS_CANCELED'].map({0: 'No', 1: 'Yes'})

# %%
df = df.copy()
df['IS_REPEATED_GUEST'] = df['IS_REPEATED_GUEST'].map({0: 'No', 1: 'Yes'})

# %%
df['AGENT'] = df['AGENT'].apply(lambda x: str(x).replace('.0', ''))

# %%
#checking with few samples
df.head(6)
# Out:
#           HOTEL IS_CANCELED  LEAD_TIME  ARRIVAL_DATE_YEAR ARRIVAL_DATE_MONTH  \
# 0  Resort Hotel          No        342               2015               July
# 1  Resort Hotel          No        737               2015               July
# 2  Resort Hotel          No          7               2015               July
# 3  Resort Hotel          No         13               2015               July
# 4  Resort Hotel          No         14               2015               July
# 6  Resort Hotel          No          0               2015               July
#
#    ARRIVAL_DATE_WEEK_NUMBER  ARRIVAL_DATE_DAY_OF_MONTH  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
# 6                        27                          1
#
# ...

# %% [markdown]
# <h3 style="color:darkblue; font-family:Georgia;text-decoration: underline;font-weight:bold">📝 DATA TYPE CONVERSION</h3>

# %%
df.loc[:, 'AGENT'] = df['AGENT'].astype(object)

# %%
df.loc[:, 'COMPANY'] = df['COMPANY'].astype(object)

# %%
df['RESERVATION_STATUS_DATE'] = pd.to_datetime(df['RESERVATION_STATUS_DATE'], errors='coerce')

# %%
df['CHILDREN'] = pd.to_numeric(df['CHILDREN'], errors='coerce')
df['CHILDREN'] = df['CHILDREN'].fillna(0).astype('int64')

# %%
#checking corrected datatypes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 87396 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   HOTEL                           87396 non-null  object
#  1   IS_CANCELED                     87396 non-null  object
#  2   LEAD_TIME                       87396 non-null  int64
#  3   ARRIVAL_DATE_YEAR               87396 non-null  int64
#  4   ARRIVAL_DATE_MONTH              87396 non-null  object
#  5   ARRIVAL_DATE_WEEK_NUMBER        87396 non-null  int64
#  6   ARRIVAL_DATE_DAY_OF_MONTH       87396 non-null  int64
#  7   STAYS_IN_WEEKEND_NIGHTS         87396 non-null  int64
#  8   STAYS_IN_WEEK_NIGHTS            87396 non-null  int64
#  9   ADULTS                          87396 non-null  int64
#  10  CHILDREN                        87396 non-null  int64
#  11  BABIES                          87396 non-null  int64
# ...

# %% [markdown]
# <h3 style="color:darkblue; font-family:Georgia; text-decoration: underline;font-weight:bold">⚠️ OUTLIER DETECTION </h3>

# %% [markdown]
# <h3 style="color:darkblue; font-family:Georgia; text-decoration: underline;font-weight:bold">Using Boxplot </h3>

# %%
numeric_columns =['LEAD_TIME',
 'ARRIVAL_DATE_YEAR',
 'ARRIVAL_DATE_WEEK_NUMBER',
 'ARRIVAL_DATE_DAY_OF_MONTH',
 'STAYS_IN_WEEKEND_NIGHTS',
 'STAYS_IN_WEEK_NIGHTS',
 'ADULTS',
 'CHILDREN',
 'BABIES',
 'PREVIOUS_CANCELLATIONS',
 'PREVIOUS_BOOKINGS_NOT_CANCELED',
 'BOOKING_CHANGES',
 'DAYS_IN_WAITING_LIST',
 'ADR',
 'REQUIRED_CAR_PARKING_SPACES',
 'TOTAL_OF_SPECIAL_REQUESTS']

for col in numeric_columns:
    plt.figure(figsize=(6,3))
    sns.boxplot(x=df[col])
    plt.title(col)
    plt.show()

# %% [markdown]
# <h3 style="color:darkblue; font-family:Georgia; text-decoration: underline;font-weight:bold">Using IQR method </h3>

# %%
numeric_columns = df.select_dtypes(include='number').columns

for col in numeric_columns:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    
    IQR = Q3 - Q1

    lower_limit = Q1 - 1.5 * IQR
    upper_limit = Q3 + 1.5 * IQR

    outliers = df[(df[col] < lower_limit) | (df[col] > upper_limit)]

    print(f"{col}: {len(outliers)} outliers")
# Out:
# LEAD_TIME: 2396 outliers
# ARRIVAL_DATE_YEAR: 0 outliers
# ARRIVAL_DATE_WEEK_NUMBER: 0 outliers
# ARRIVAL_DATE_DAY_OF_MONTH: 0 outliers
# STAYS_IN_WEEKEND_NIGHTS: 220 outliers
# STAYS_IN_WEEK_NIGHTS: 1531 outliers
# ADULTS: 22899 outliers
# CHILDREN: 8364 outliers
# BABIES: 914 outliers
# PREVIOUS_CANCELLATIONS: 1685 outliers
# PREVIOUS_BOOKINGS_NOT_CANCELED: 3545 outliers
# BOOKING_CHANGES: 15902 outliers
# DAYS_IN_WAITING_LIST: 860 outliers
# ADR: 2490 outliers
# REQUIRED_CAR_PARKING_SPACES: 7313 outliers
# TOTAL_OF_SPECIAL_REQUESTS: 2673 outliers

# %%
df_cleaned_data = df.copy()

cols = ['LEAD_TIME', 'ADR', 'DAYS_IN_WAITING_LIST']

for col in cols:
    Q1 = df_cleaned_data[col].quantile(0.25)
    Q3 = df_cleaned_data[col].quantile(0.75)

    IQR = Q3 - Q1

    lower_limit = Q1 - 1.5 * IQR
    upper_limit = Q3 + 1.5 * IQR

    df_cleaned_data = df_cleaned_data[(df_cleaned_data[col] >= lower_limit) & (df_cleaned_data[col] <= upper_limit)]

print("Original Shape:", df.shape)
print("Cleaned Shape:", df_cleaned_data.shape)
# Out:
# Original Shape: (87396, 32)
# Cleaned Shape: (81911, 32)

# %% [markdown]
# <div style="
#     background-color: #e8f5e9;
#     border: 1px solid #81c784;
#     padding: 15px;
#     margin: 10px 0;
#     width: 100%;
#     box-sizing: border-box;
# ">
#
# <p style="
#     color: #1b5e20;
#     font-family: Arial;
#     font-size: 17px;
#     margin: 0;
# ">
# 💡 <strong>Insight:</strong> The Interquartile Range (IQR) method was used to identify and remove extreme values by filtering observations that fall below Q1 − 1.5 × IQR or above Q3 + 1.5 × IQR.
# It was applied to remove extreme values from <b>Lead Time</b>, <b>ADR</b>, and <b>Days in Waiting List</b>. After outlier treatment, the dataset size decreased from <b>87,396</b> to <b>81,911</b> records, helping reduce the influence of unusually large values while preserving the majority of booking information for analysis.
#
# </p>
#
# </div>

# %% [markdown]
# <div style="
#     background: linear-gradient(135deg, #d9f3ff, #b2dfdb);
#     border: 4px solid #008080;
#     border-radius: 10px;
#     padding: 5px;
#     margin: 15px 0;
#     box-shadow: 0px 6px 15px rgba(0,0,0,0.2);
#     display: flex;
#     justify-content: space-between;
#     align-items: center;
# ">
#
# <div style="flex: 4;">
#     <h2 style="color:darkblue; font-family:Georgia; font-weight:bold;text-decoration: underline">
# 9.EXPLORATORY DATA ANALYSIS (EDA)
# </h2>

# %% [markdown]
# <h3 style="color:darkblue; font-family:Georgia; text-decoration: underline; font-weight:bold">
# 🗂️ FILTERING DATA
# </h3>

# %% [markdown]
# <div style="
#     background: linear-gradient(135deg, #e3f2fd, #b2dfdb);
#     border-left: 4px solid #00796b;
#     border-radius: 12px;
#     padding: 15px 20px;
#     margin: 15px 0;
#     box-shadow: 0px 4px 8px rgba(0,0,0,0.15);
# ">
#
# <p style="
#     color: #1a237e;
#     font-size: 18px;
#     font-family: Arial;
#     margin: 0;
# ">
# <b>1.How are cancelled bookings and non-cancelled bookings distributed across the dataset❓</b>
# </p>
#
# </div>

# %%
Canceled_bookings = df_cleaned_data[df_cleaned_data['IS_CANCELED'] == 'Yes']
Non_cancelled_bookings = df_cleaned_data[df_cleaned_data['IS_CANCELED'] == 'No']

# %%
print("Number of bookings that were canceled:", len(Canceled_bookings))
print("Number of bookings that were not canceled:", len(Non_cancelled_bookings))
# Out:
# Number of bookings that were canceled: 21765
# Number of bookings that were not canceled: 60146

# %% [markdown]
# <div style="
#     background-color: #e8f5e9;
#     border: 1px solid #81c784;
#     padding: 15px;
#     margin: 10px 0;
#     width: 100%;
#     box-sizing: border-box;
# ">
#
# <p style="
#     color: #1b5e20;
#     font-family: Arial;
#     font-size: 17px;
#     margin: 0;
# ">
# 💡 <strong>Insight:</strong> Out of 81911 bookings, 21765 were cancelled and 60146 were not cancelled.
# </p>
#
# </div>

# %% [markdown]
# <div style="
#     background: linear-gradient(135deg, #e3f2fd, #b2dfdb);
#     border-left: 4px solid #00796b;
#     border-radius: 12px;
#     padding: 15px 20px;
#     margin: 15px 0;
#     box-shadow: 0px 4px 8px rgba(0,0,0,0.15);
# ">
#
# <p style="
#     color: #1a237e;
#     font-size: 18px;
#     font-family: Arial;
#     margin: 0;
# ">
# <b>2. Howmany customers were there with special request❓
# </p>
#
# </div>

# %%
Special_requests = df_cleaned_data[df_cleaned_data['TOTAL_OF_SPECIAL_REQUESTS'] > 0]

# %%
print("Number of special requests made:", len(Special_requests))
# Out:
# Number of special requests made: 41050

# %% [markdown]
# <div style="
#     background-color: #e8f5e9;
#     border: 1px solid #81c784;
#     padding: 15px;
#     margin: 10px 0;
#     width: 100%;
#     box-sizing: border-box;
# ">
#
# <p style="
#     color: #1b5e20;
#     font-family: Arial;
#     font-size: 17px;
#     margin: 0;
# ">
# 💡 <strong>Insight:</strong> Customers making special requests may have different booking patterns and service expectations.
# </p>
#
# </div>

# %% [markdown]
# <div style="
#     background: linear-gradient(135deg, #e3f2fd, #b2dfdb);
#     border-left: 4px solid #00796b;
#     border-radius: 12px;
#     padding: 15px 20px;
#     margin: 15px 0;
#     box-shadow: 0px 4px 8px rgba(0,0,0,0.15);
# ">
#
# <p style="
#     color: #1a237e;
#     font-size: 18px;
#     font-family: Arial;
#     margin: 0;
# ">
# <b>3. Are customers who book well in advance more likely to cancel their reservations❓
# </p>
#
# </div>

# %%
Booked_early = df_cleaned_data[(df_cleaned_data['LEAD_TIME'] > 100) & (df['IS_CANCELED'] == 'Yes')]
Not_Booked_early = df_cleaned_data[(df_cleaned_data['LEAD_TIME'] > 100) & (df['IS_CANCELED'] == 'No')]

# %%
print("Number of Customers Who Book Early but Still Cancel:", len(Booked_early)) 
print("Number of Customers Who Book Early but DONT Cancel:", len(Not_Booked_early))
# Out:
# Number of Customers Who Book Early but Still Cancel: 8509
# Number of Customers Who Book Early but DONT Cancel: 15336

# %% [markdown]
# <div style="
#     background-color: #e8f5e9;
#     border: 1px solid #81c784;
#     padding: 15px;
#     margin: 10px 0;
#     width: 100%;
#     box-sizing: border-box;
# ">
#
# <p style="
#     color: #1b5e20;
#     font-family: Arial;
#     font-size: 17px;
#     margin: 0;
# ">
# 💡 <strong>Insight:</strong> Customers who book several months in advance may have a little tendency to cancel due to changes in travel plans.
# </p>
#
# </div>

# %% [markdown]
# <div style="
#     background: linear-gradient(135deg, #e3f2fd, #b2dfdb);
#     border-left: 4px solid #00796b;
#     border-radius: 12px;
#     padding: 15px 20px;
#     margin: 15px 0;
#     box-shadow: 0px 4px 8px rgba(0,0,0,0.15);
# ">
#
# <p style="
#     color: #1a237e;
#     font-size: 18px;
#     font-family: Arial;
#     margin: 0;
# ">
# <b>4. Are repeat guests less likely to cancel their hotel reservations❓
# </p>
#
# </div>

# %%
Canceled = df_cleaned_data[(df_cleaned_data['IS_REPEATED_GUEST'] == 'Yes') & (df_cleaned_data['IS_CANCELED'] == 'Yes')]
Not_canceled = df_cleaned_data[(df_cleaned_data['IS_REPEATED_GUEST'] == 'Yes') & (df_cleaned_data['IS_CANCELED'] == 'No')]

# %%
print(len(Canceled))
print(len(Not_canceled))
# Out:
# 246
# 3101

# %% [markdown]
# <div style="
#     background-color: #e8f5e9;
#     border: 1px solid #81c784;
#     padding: 15px;
#     margin: 10px 0;
#     width: 100%;
#     box-sizing: border-box;
# ">
#
# <p style="
#     color: #1b5e20;
#     font-family: Arial;
#     font-size: 17px;
#     margin: 0;
# ">
# 💡 <strong>Insight:</strong> Repeat guests demonstrate stronger loyalty and are less likely to cancel reservations.
# </p>
#
# </div>

# %% [markdown]
# <div style="
#     background: linear-gradient(135deg, #e3f2fd, #b2dfdb);
#     border-left: 4px solid #00796b;
#     border-radius: 12px;
#     padding: 15px 20px;
#     margin: 15px 0;
#     box-shadow: 0px 4px 8px rgba(0,0,0,0.15);
# ">
#
# <p style="
#     color: #1a237e;
#     font-size: 18px;
#     font-family: Arial;
#     margin: 0;
# ">
# <b>5. Are customers with a history of cancellations more likely to cancel future bookings❓
# </p>
#
# </div>

# %%
Canceled1 = df_cleaned_data[(df_cleaned_data['PREVIOUS_CANCELLATIONS']> 0) & (df_cleaned_data['IS_CANCELED'] == 'Yes')]
Not_canceled2= df_cleaned_data[(df_cleaned_data['PREVIOUS_CANCELLATIONS']> 0) & (df_cleaned_data['IS_CANCELED'] == 'No')]

# %%
print(len(Canceled1))
print(len(Not_canceled2))
# Out:
# 984
# 539

# %% [markdown]
# <div style="
#     background-color: #e8f5e9;
#     border: 1px solid #81c784;
#     padding: 15px;
#     margin: 10px 0;
#     width: 100%;
#     box-sizing: border-box;
# ">
#
# <p style="
#     color: #1b5e20;
#     font-family: Arial;
#     font-size: 17px;
#     margin: 0;
# ">
# 💡 <strong>Insight:</strong> Customers with a history of cancellations may be more likely to cancel future bookings as well.
# </p>
#
# </div>

# %% [markdown]
# <div style="
#     background: linear-gradient(135deg, #e3f2fd, #b2dfdb);
#     border-left: 4px solid #00796b;
#     border-radius: 12px;
#     padding: 15px 20px;
#     margin: 15px 0;
#     box-shadow: 0px 4px 8px rgba(0,0,0,0.15);
# ">
#
# <p style="
#     color: #1a237e;
#     font-size: 18px;
#     font-family: Arial;
#     margin: 0;
# ">
# <b>6. How often does the assigned room differ from the room originally reserved by guests❓
# </p>
#
# </div>

# %%
print(len(df_cleaned_data[df_cleaned_data['RESERVED_ROOM_TYPE'] != df_cleaned_data['ASSIGNED_ROOM_TYPE']]))
# Out:
# 12540

# %% [markdown]
# <div style="
#     background-color: #e8f5e9;
#     border: 1px solid #81c784;
#     padding: 15px;
#     margin: 10px 0;
#     width: 100%;
#     box-sizing: border-box;
# ">
#
# <p style="
#     color: #1b5e20;
#     font-family: Arial;
#     font-size: 17px;
#     margin: 0;
# ">
# 💡 <strong>Insight:</strong> Room reassignment occurs in some bookings, possibly due to upgrades, overbooking, or operational requirements.
# </p>
#
# </div>

# %% [markdown]
# <div style="
#     background: linear-gradient(135deg, #e3f2fd, #b2dfdb);
#     border-left: 4px solid #00796b;
#     border-radius: 12px;
#     padding: 15px 20px;
#     margin: 15px 0;
#     box-shadow: 0px 4px 8px rgba(0,0,0,0.15);
# ">
#
# <p style="
#     color: #1a237e;
#     font-size: 18px;
#     font-family: Arial;
#     margin: 0;
# ">
# <b>7. which are the bookings that has ADR > 100❓
# </p>
#
# </div>

# %%
High_ADRs = df_cleaned_data[df_cleaned_data['ADR'] > 100]

# %%
print("Number of bookings that has ADR>100:", len(High_ADRs))
# Out:
# Number of bookings that has ADR>100: 38359

# %%
print((len(High_ADRs) / len(df_cleaned_data)) * 100)
print(High_ADRs['HOTEL'].value_counts())
# Out:
# 46.83009607989159
# HOTEL
# City Hotel      27554
# Resort Hotel    10805
# Name: count, dtype: int64

# %% [markdown]
# <div style="
#     background-color: #e8f5e9;
#     border: 1px solid #81c784;
#     padding: 15px;
#     margin: 10px 0;
#     width: 100%;
#     box-sizing: border-box;
# ">
#
# <p style="
#     color: #1b5e20;
#     font-family: Arial;
#     font-size: 17px;
#     margin: 0;
# ">
# 💡 <strong>Insight:</strong> Bookings with ADR greater than 100 represent higher-value reservations and may indicate premium room categories, peak-season demand, or customers willing to pay higher rates for accommodation. Most high-value bookings (ADR &gt; 100) are associated with City Hotels, indicating higher room pricing in this hotel category.
# </p>
#
# </div>

# %% [markdown]
# <h3 style="color:darkblue; font-family:Georgia; text-decoration: underline;font-weight:bold">ADR Analysis</h3>

# %%
# Number of rows with ADR = 0
(df_cleaned_data['ADR'] == 0).sum()
# Out:
# np.int64(1707)

# %%
# Percentage
(df_cleaned_data['ADR'] == 0).mean() * 100
# Out:
# np.float64(2.0839691860678053)

# %% [markdown]
# 2.08% of bookings have an ADR value of 0.

# %%
df_cleaned_data[df_cleaned_data['ADR'] == 0]['IS_CANCELED'].value_counts()
# Out:
# IS_CANCELED
# No     1544
# Yes     163
# Name: count, dtype: int64

# %% [markdown]
# <div style="
#     background-color: #e8f5e9;
#     border: 1px solid #81c784;
#     padding: 15px;
#     margin: 10px 0;
#     width: 100%;
#     box-sizing: border-box;
# ">
#
# <p style="
#     color: #1b5e20;
#     font-family: Arial;
#     font-size: 17px;
#     margin: 0;
#     line-height: 1.6;
# ">
# 💡 <strong>Insight:</strong> Nearly 90% of bookings with ADR = 0 were not canceled, indicating that zero ADR values are not primarily caused by cancellations.
# </p>
#
# </div>

# %%
df_cleaned_data[df_cleaned_data['ADR']== 0]['HOTEL'].value_counts()
# Out:
# HOTEL
# City Hotel      1046
# Resort Hotel     661
# Name: count, dtype: int64

# %% [markdown]
# <div style="
#     background-color: #e8f5e9;
#     border: 1px solid #81c784;
#     padding: 15px;
#     margin: 10px 0;
#     width: 100%;
#     box-sizing: border-box;
# ">
# <p style="
#     color: #1b5e20;
#     font-family: Arial;
#     font-size: 17px;
#     margin: 0;
# ">
# 💡 <strong>Insight:</strong> ADR = 0 bookings are more common in City Hotels than Resort Hotels.
# </p>
# </div>

# %%
df_cleaned_data[df_cleaned_data['ADR']== 0]['CUSTOMER_TYPE'].value_counts()
# Out:
# CUSTOMER_TYPE
# Transient          1344
# Transient-Party     325
# Contract             23
# Group                15
# Name: count, dtype: int64

# %% [markdown]
# <div style="
#     background-color: #e8f5e9;
#     border: 1px solid #81c784;
#     padding: 15px;
#     margin: 10px 0;
#     width: 100%;
#     box-sizing: border-box;
# ">
# <p style="
#     color: #1b5e20;
#     font-family: Arial;
#     font-size: 17px;
#     margin: 0;
# ">
# 💡 <strong>Insight:</strong> More than 75% of ADR = 0 bookings belong to transient customers, suggesting that individual travelers account for most zero-revenue reservations.
# </p>
# </div>

# %%
df_cleaned_data[df_cleaned_data['ADR'] == 0]['RESERVATION_STATUS'].value_counts()
# Out:
# RESERVATION_STATUS
# Check-Out    1544
# Canceled      138
# No-Show        25
# Name: count, dtype: int64

# %% [markdown]
# <div style="
#     background-color: #e8f5e9;
#     border: 1px solid #81c784;
#     padding: 15px;
#     margin: 10px 0;
#     width: 100%;
#     box-sizing: border-box;
# ">
# <p style="
#     color: #1b5e20;
#     font-family: Arial;
#     font-size: 17px;
#     margin: 0;
# ">
# 💡 <strong>Insight:</strong> The majority of ADR = 0 bookings resulted in successful check-outs rather than cancellations or no-shows.
# </p>
# </div>

# %% [markdown]
# <h3 style="color:darkblue; font-family:Georgia; text-decoration: underline;font-weight:bold">ADR Analysis Report</h3>

# %% [markdown]
# <div style="
#     background: linear-gradient(135deg, #e3f2fd, #b2dfdb);
#     border-left: 5px solid #00796b;
#     padding: 18px;
#     margin: 15px 0;
#     width: 100%;
#     box-sizing: border-box;
# ">
# <p style="
#     color: #004d40;
#     font-family: Arial;
#     font-size: 17px;
#     line-height: 1.8;
#     margin: 0;
# ">
# 📌 <strong>Key Finding:</strong> During exploratory data analysis, 1,707 bookings were found with an ADR value of zero. Further investigation revealed that approximately 90% of these bookings were not canceled and had a reservation status of <b>"Check-Out"</b>. Additionally, most zero-ADR bookings belonged to <b>Transient</b> customers and were more common in <b>City Hotels</b>. This suggests that ADR = 0 values may represent complimentary stays, promotional offers, package bookings, or other non-standard revenue situations rather than booking cancellations.
# </p>
# </div>

# %% [markdown]
# <h3 style="color:darkblue; font-family:Georgia; text-decoration: underline; font-weight:bold">
# 📈 GROUPING AND AGGREGATING DATA
# </h3>

# %% [markdown]
# <div style="
#     background: linear-gradient(135deg, #e3f2fd, #b2dfdb);
#     border-left: 4px solid #00796b;
#     border-radius: 12px;
#     padding: 15px 20px;
#     margin: 15px 0;
#     box-shadow: 0px 4px 8px rgba(0,0,0,0.15);
# ">
#
# <p style="
#     color: #1a237e;
#     font-size: 18px;
#     font-family: Arial;
#     margin: 0;
# ">
# <b>1. Which hotel type receives the highest average ADR❓
# </p>
#
# </div>

# %%
df_cleaned_data.groupby('HOTEL')['ADR'].mean()
# Out:
# HOTEL
# City Hotel      109.484633
# Resort Hotel     90.738660
# Name: ADR, dtype: float64

# %% [markdown]
# <div style="
#     background-color: #e8f5e9;
#     border: 1px solid #81c784;
#     padding: 15px;
#     margin: 10px 0;
#     width: 100%;
#     box-sizing: border-box;
# ">
# <p style="
#     color: #1b5e20;
#     font-family: Arial;
#     font-size: 17px;
#     margin: 0;
# ">
# 💡 <strong>Insight:</strong> City Hotels have a higher average ADR (109.48) than Resort Hotels (90.74), indicating that City Hotels generally generate more revenue per room booking.
# </p>
# </div>

# %% [markdown]
# <div style="
#     background: linear-gradient(135deg, #e3f2fd, #b2dfdb);
#     border-left: 4px solid #00796b;
#     border-radius: 12px;
#     padding: 15px 20px;
#     margin: 15px 0;
#     box-shadow: 0px 4px 8px rgba(0,0,0,0.15);
# ">
#
# <p style="
#     color: #1a237e;
#     font-size: 18px;
#     font-family: Arial;
#     margin: 0;
# ">
# <b>2. Which customer type makes the most hotel reservations❓
# </p>
#
# </div>

# %%
df_cleaned_data.groupby('CUSTOMER_TYPE').size()
# Out:
# CUSTOMER_TYPE
# Contract            2921
# Group                503
# Transient          68312
# Transient-Party    10175
# dtype: int64

# %% [markdown]
# <div style="
#     background-color: #e8f5e9;
#     border: 1px solid #81c784;
#     padding: 15px;
#     margin: 10px 0;
#     width: 100%;
#     box-sizing: border-box;
# ">
# <p style="
#     color: #1b5e20;
#     font-family: Arial;
#     font-size: 17px;
#     margin: 0;
# ">
# 💡 <strong>Insight:</strong> Transient customers account for the vast majority of hotel reservations, indicating that individual travelers represent the primary customer segment for both hotel types.
# </p>
# </div>

# %% [markdown]
# <div style="
#     background: linear-gradient(135deg, #e3f2fd, #b2dfdb);
#     border-left: 4px solid #00796b;
#     border-radius: 12px;
#     padding: 15px 20px;
#     margin: 15px 0;
#     box-shadow: 0px 4px 8px rgba(0,0,0,0.15);
# ">
#
# <p style="
#     color: #1a237e;
#     font-size: 18px;
#     font-family: Arial;
#     margin: 0;
# ">
# <b>3. How does reservation status vary between City Hotels and Resort Hotels❓
# </p>
#
# </div>

# %%
df_cleaned_data.groupby('HOTEL')['RESERVATION_STATUS'].value_counts()
# Out:
# HOTEL         RESERVATION_STATUS
# City Hotel    Check-Out             35983
#               Canceled              14136
#               No-Show                 737
# Resort Hotel  Check-Out             24163
#               Canceled               6641
#               No-Show                 251
# Name: count, dtype: int64

# %% [markdown]
# <div style="
#     background-color: #e8f5e9;
#     border: 1px solid #81c784;
#     padding: 15px;
#     margin: 10px 0;
#     width: 100%;
#     box-sizing: border-box;
# ">
# <p style="
#     color: #1b5e20;
#     font-family: Arial;
#     font-size: 17px;
#     margin: 0;
# ">
# 💡 <strong>Insight:</strong> Both City Hotels and Resort Hotels recorded more successful check-outs than cancellations, although City Hotels experienced a noticeably higher number of cancellations compared to Resort Hotels.
# </p>
# </div>

# %% [markdown]
# <div style="
#     background: linear-gradient(135deg, #e3f2fd, #b2dfdb);
#     border-left: 4px solid #00796b;
#     border-radius: 12px;
#     padding: 15px 20px;
#     margin: 15px 0;
#     box-shadow: 0px 4px 8px rgba(0,0,0,0.15);
# ">
#
# <p style="
#     color: #1a237e;
#     font-size: 18px;
#     font-family: Arial;
#     margin: 0;
# ">
# <b>4. Which hotel type has customers with the highest number of previous cancellations❓
# </p>
#
# </div>

# %%
df_cleaned_data.groupby('HOTEL')['PREVIOUS_CANCELLATIONS'].sum()
# Out:
# HOTEL
# City Hotel      1705
# Resort Hotel     730
# Name: PREVIOUS_CANCELLATIONS, dtype: int64

# %% [markdown]
# <div style="
#     background-color: #e8f5e9;
#     border: 1px solid #81c784;
#     padding: 15px;
#     margin: 10px 0;
#     width: 100%;
#     box-sizing: border-box;
# ">
# <p style="
#     color: #1b5e20;
#     font-family: Arial;
#     font-size: 17px;
#     margin: 0;
# ">
# 💡 <strong>Insight:</strong> Customers booking City Hotels have a higher history of previous cancellations than those booking Resort Hotels, suggesting a greater tendency toward cancellation behavior in this segment.
# </p>
# </div>

# %% [markdown]
# <div style="
#     background: linear-gradient(135deg, #e3f2fd, #b2dfdb);
#     border-left: 4px solid #00796b;
#     border-radius: 12px;
#     padding: 15px 20px;
#     margin: 15px 0;
#     box-shadow: 0px 4px 8px rgba(0,0,0,0.15);
# ">
#
# <p style="
#     color: #1a237e;
#     font-size: 18px;
#     font-family: Arial;
#     margin: 0;
# ">
# <b>5. What is the maximum ADR by hotel type❓
# </p>
#
# </div>

# %%
df_cleaned_data.groupby('HOTEL')['ADR'].max()
# Out:
# HOTEL
# City Hotel      229.0
# Resort Hotel    229.0
# Name: ADR, dtype: float64

# %% [markdown]
# <div style="
#     background-color: #e8f5e9;
#     border: 1px solid #81c784;
#     padding: 15px;
#     margin: 10px 0;
#     width: 100%;
#     box-sizing: border-box;
# ">
# <p style="
#     color: #1b5e20;
#     font-family: Arial;
#     font-size: 17px;
#     margin: 0;
# ">
# 💡 <strong>Insight:</strong> Both City Hotels and Resort Hotels recorded the same maximum ADR of 229, indicating that the highest-priced room bookings reached a similar revenue level in both hotel categories.
# </p>
# </div>

# %% [markdown]
# <div style="
#     background: linear-gradient(135deg, #e3f2fd, #b2dfdb);
#     border-left: 4px solid #00796b;
#     border-radius: 12px;
#     padding: 15px 20px;
#     margin: 15px 0;
#     box-shadow: 0px 4px 8px rgba(0,0,0,0.15);
# ">
#
# <p style="
#     color: #1a237e;
#     font-size: 18px;
#     font-family: Arial;
#     margin: 0;
# ">
# <b>6. What is the median lead time for each hotel type❓
# </p>
#
# </div>

# %%
df_cleaned_data.groupby('HOTEL')['LEAD_TIME'].median()
# Out:
# HOTEL
# City Hotel      48.0
# Resort Hotel    41.0
# Name: LEAD_TIME, dtype: float64

# %% [markdown]
# <div style="
#     background-color: #e8f5e9;
#     border: 1px solid #81c784;
#     padding: 15px;
#     margin: 10px 0;
#     width: 100%;
#     box-sizing: border-box;
# ">
# <p style="
#     color: #1b5e20;
#     font-family: Arial;
#     font-size: 17px;
#     margin: 0;
# ">
# 💡 <strong>Insight:</strong> The median lead time is higher for City Hotels (48 days) than for Resort Hotels (41 days), suggesting that guests tend to book City Hotel stays further in advance.
# </p>
# </div>

# %% [markdown]
# <h3 style="color:darkblue; font-family:Georgia; text-decoration: underline; font-weight:bold">
# 1️⃣ UNIVARIATE ANALYSIS
# </h3>

# %% [markdown]
# <div style="
#     background: linear-gradient(135deg, #e3f2fd, #b2dfdb);
#     border-left: 4px solid #00796b;
#     border-radius: 12px;
#     padding: 15px 20px;
#     margin: 15px 0;
#     box-shadow: 0px 4px 8px rgba(0,0,0,0.15);
# ">
#
# <p style="
#     color: #1a237e;
#     font-size: 18px;
#     font-family: Arial;
#     margin: 0;
# ">
# <b>1. Which hotel type receives the highest number of bookings❓</b>
# </p>
#
# </div>

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=df_cleaned_data, x='HOTEL', color='orange')
plt.title('Distribution of Hotel Types')
plt.show()

# %% [markdown]
# <div style="
#     background-color: #e8f5e9;
#     border: 1px solid #81c784;
#     padding: 15px;
#     margin: 10px 0;
#     width: 100%;
#     box-sizing: border-box;
# ">
# <p style="
#     color: #1b5e20;
#     font-family: Arial;
#     font-size: 17px;
#     margin: 0;
# ">
# 💡 <strong>Insight:</strong> City Hotels receive significantly more bookings than Resort Hotels, indicating a stronger customer preference. Their popularity may be driven by convenient locations, better accessibility, and services that cater to a wide range of travelers, making them a preferred accommodation choice.
# </p>
# </div>

# %% [markdown]
# <div style="
#     background: linear-gradient(135deg, #e3f2fd, #b2dfdb);
#     border-left: 4px solid #00796b;
#     border-radius: 12px;
#     padding: 15px 20px;
#     margin: 15px 0;
#     box-shadow: 0px 4px 8px rgba(0,0,0,0.15);
# ">
#
# <p style="
#     color: #1a237e;
#     font-size: 18px;
#     font-family: Arial;
#     margin: 0;
# ">
# <b>2. How are hotel bookings distributed across different customer types❓</b>
# </p>
#
# </div>

# %%
customer_type = df_cleaned_data['CUSTOMER_TYPE'].value_counts()
color = ['gold','yellowgreen','lightcoral','red']
plt.figure(figsize=(6,6))
plt.pie(customer_type,labels=customer_type.index,autopct='%1.1f%%',colors=color)
plt.title('Distribution of Customer Types')
plt.show()

# %% [markdown]
# <div style="
#     background-color: #e8f5e9;
#     border: 1px solid #81c784;
#     padding: 15px;
#     margin: 10px 0;
#     width: 100%;
#     box-sizing: border-box;
# ">
# <p style="
#     color: #1b5e20;
#     font-family: Arial;
#     font-size: 17px;
#     margin: 0;
# ">
# 💡 <strong>Insight:</strong> From this pie-chart we can conclude that Transiet type of customer contributes almost 83.4% of all types of customers, then comes the Tansient-party type. Group and Contract type of customers contributes only a very little percent.
# </p>
# </div>

# %% [markdown]
# <div style="
#     background: linear-gradient(135deg, #e3f2fd, #b2dfdb);
#     border-left: 4px solid #00796b;
#     border-radius: 12px;
#     padding: 15px 20px;
#     margin: 15px 0;
#     box-shadow: 0px 4px 8px rgba(0,0,0,0.15);
# ">
#
# <p style="
#     color: #1a237e;
#     font-size: 18px;
#     font-family: Arial;
#     margin: 0;
# ">
# <b>3. Does the Average Daily Rate (ADR) exhibit any skewness or unusual patterns in its distribution❓</b>
# </p>
#
# </div>

# %%
plt.figure(figsize=(8,4))
sns.histplot(data=df_cleaned_data, x='ADR', bins=30,color='cyan', kde=True)
plt.title('Distribution of ADR')
plt.show()

# %% [markdown]
# <div style="
#     background-color: #e8f5e9;
#     border: 1px solid #81c784;
#     padding: 15px;
#     margin: 10px 0;
#     width: 100%;
#     box-sizing: border-box;
# ">
# <p style="
#     color: #1b5e20;
#     font-family: Arial;
#     font-size: 17px;
#     margin: 0;
# ">
# 💡 <strong>Insight:</strong> The ADR distribution exhibits a relatively smooth and balanced pattern, suggesting the absence of significant skewness in the data. A small peak is observed at an ADR value of zero; however, previous analysis revealed that these bookings were not cancellations, as many of them had a "Check-Out" reservation status. This indicates that the zero ADR values may be associated with complimentary stays, promotional offers, package deals, or other special booking arrangements. Therefore, these records represent valid bookings and should be retained in the analysis. Overall, the ADR distribution appears fairly uniform, reflecting a well-spread range of room rates across hotel bookings.
# </p>
# </div>

# %% [markdown]
# <div style="
#     background: linear-gradient(135deg, #e3f2fd, #b2dfdb);
#     border-left: 4px solid #00796b;
#     border-radius: 12px;
#     padding: 15px 20px;
#     margin: 15px 0;
#     box-shadow: 0px 4px 8px rgba(0,0,0,0.15);
# ">
#
# <p style="
#     color: #1a237e;
#     font-size: 18px;
#     font-family: Arial;
#     margin: 0;
# ">
# <b>4. Which meal types are most preferred by hotel guests❓</b>
# </p>
#
# </div>

# %%
plt.figure(figsize=(8,5))

sns.countplot(data=df_cleaned_data,x='MEAL',hue='MEAL',palette='rocket', legend=False)
plt.title('Meal Types Preferred by Customers')
plt.show()

# %% [markdown]
# <div style="
#     background-color: #e8f5e9;
#     border: 1px solid #81c784;
#     padding: 15px;
#     margin: 10px 0;
#     width: 100%;
#     box-sizing: border-box;
# ">
# <p style="
#     color: #1b5e20;
#     font-family: Arial;
#     font-size: 17px;
#     margin: 0;
# ">
# 💡 <strong>Insight:</strong> The analysis reveals that more than 75% of guests opt for the BB (Bed & Breakfast) meal plan, making it the most preferred meal package by a substantial margin. This strong preference suggests that guests may value the convenience of having breakfast included while choosing to explore alternative dining options for lunch and dinner. Possible factors influencing this behavior could include food quality perceptions, greater variety available outside the hotel, or the higher cost of full-board meal packages. Conducting a deeper investigation into guest dining preferences, meal pricing, and satisfaction levels could provide valuable insights into why the BB plan is significantly more popular than other meal options.
# </p>
# </div>

# %% [markdown]
# <div style="
#     background: linear-gradient(135deg, #e3f2fd, #b2dfdb);
#     border-left: 4px solid #00796b;
#     border-radius: 12px;
#     padding: 15px 20px;
#     margin: 15px 0;
#     box-shadow: 0px 4px 8px rgba(0,0,0,0.15);
# ">
#
# <p style="
#     color: #1a237e;
#     font-size: 18px;
#     font-family: Arial;
#     margin: 0;
# ">
# <b>5. Who are the top 10 agents and companies driving hotel reservations❓
# </p>
#
# </div>

# %%
top_agents = df_cleaned_data['AGENT'].value_counts().head(10)

fig = px.bar(
    x=top_agents.index.astype(str),
    y=top_agents.values,
    text=top_agents.values,
    title='Top 10 Agents by Number of Bookings',
    color_discrete_sequence=['green']
)

fig.update_layout(
    xaxis_title='Agent ID',
    yaxis_title='Bookings'
)

fig.show()

# %%
top_companies = df_cleaned_data['COMPANY'].value_counts().head(10)

fig = px.bar(
    x=top_companies.index.astype(str),
    y=top_companies.values,
    text=top_companies.values,
    title='Top 10 Companies by Number of Bookings',
    color_discrete_sequence=['red']
)

fig.update_layout(
    xaxis_title='Company ID',
    yaxis_title='Bookings'
)


fig.show()

# %% [markdown]
# <div style="
#     background-color: #e8f5e9;
#     border: 1px solid #81c784;
#     padding: 15px;
#     margin: 10px 0;
#     width: 100%;
#     box-sizing: border-box;
# ">
# <p style="
#     color: #1b5e20;
#     font-family: Arial;
#     font-size: 17px;
#     margin: 0;
# ">
# 💡 <strong>Insight:</strong> Agent ID <b>9</b> was the leading booking agent with <b>27,932 bookings</b>. The top company is ID  <b>40</b> contributed <b>851 bookings</b>, while a large majority of reservations (<b>76,820</b>) were made without any company involvement. This indicates that hotel bookings rely much more on individual travelers and travel agents than on corporate clients.
# </p>
# </div>

# %% [markdown]
# <h3 style="color:darkblue; font-family:Georgia; text-decoration: underline; font-weight:bold">
# 2️⃣ BIVARIATE ANALYSIS
# </h3>

# %% [markdown]
# <div style="
#     background: linear-gradient(135deg, #e3f2fd, #b2dfdb);
#     border-left: 4px solid #00796b;
#     border-radius: 12px;
#     padding: 15px 20px;
#     margin: 15px 0;
#     box-shadow: 0px 4px 8px rgba(0,0,0,0.15);
# ">
#
# <p style="
#     color: #1a237e;
#     font-size: 18px;
#     font-family: Arial;
#     margin: 0;
# ">
# <b>1. How do market segments differ between City Hotels and Resort Hotels❓
# </p>
#
# </div>

# %%
pivot_table = pd.pivot_table(
    df_cleaned_data,
    index='MARKET_SEGMENT',
    columns='HOTEL',
    aggfunc='size',
    fill_value=0
)
pivot_table.style.background_gradient(cmap='Oranges')
# Out:
# <style type="text/css">
# #T_3a400_row0_col0 {
#   background-color: #fff5ea;
#   color: #000000;
# }
# #T_3a400_row0_col1, #T_3a400_row7_col0, #T_3a400_row7_col1 {
#   background-color: #fff5eb;
#   color: #000000;
# }
# #T_3a400_row1_col0, #T_3a400_row1_col1 {
#   background-color: #fff4e8;
#   color: #000000;
# }
# #T_3a400_row2_col0 {
#   background-color: #feeddc;
#   color: #000000;
# }
# #T_3a400_row2_col1 {
#   background-color: #fee5cc;
#   color: #000000;
# }
# #T_3a400_row3_col0 {
#   background-color: #fee0c3;
#   color: #000000;
# }
# #T_3a400_row3_col1 {
#   background-color: #fdac67;
#   color: #000000;
# }
# #T_3a400_row4_col0 {
#   background-color: #ffeedd;
#   color: #000000;
# }
# #T_3a400_row4_col1 {
#   background-color: #fee6cf;
#   color: #000000;
# }
# #T_3a400_row5_col0 {
#   background-color: #fddab6;
#   color: #000000;
# }
# #T_3a400_row5_col1 {
#   background-color: #fda35c;
#   color: #000000;
# }
# #T_3a400_row6_col0, #T_3a400_row6_col1 {
# ...

# %% [markdown]
# <div style="
#     background-color: #e8f5e9;
#     border: 1px solid #81c784;
#     padding: 15px;
#     margin: 10px 0;
#     width: 100%;
#     box-sizing: border-box;
# ">
# <p style="
#     color: #1b5e20;
#     font-family: Arial;
#     font-size: 17px;
#     margin: 0;
# ">
# 💡 <strong>Insight:</strong>Online Travel Agents (Online TA) are the market segment for both hotel types, accounting for <b>34,015</b>bookings in City Hotels and <b>15,028</b> bookings in Resort Hotels. This indicates that online travel platforms are the primary source of reservations, especially for City Hotels.
# </p>
# </div>

# %% [markdown]
# <div style="
#     background: linear-gradient(135deg, #e3f2fd, #b2dfdb);
#     border-left: 4px solid #00796b;
#     border-radius: 12px;
#     padding: 15px 20px;
#     margin: 15px 0;
#     box-shadow: 0px 4px 8px rgba(0,0,0,0.15);
# ">
#
# <p style="
#     color: #1a237e;
#     font-size: 18px;
#     font-family: Arial;
#     margin: 0;
# ">
# <b>2. How do room assignment patterns differ between Resort Hotels and City Hotels❓
# </p>
#
# </div>

# %%
plt.figure(figsize=(12,6))
sns.countplot(data=df_cleaned_data, x='ASSIGNED_ROOM_TYPE', hue='HOTEL', palette='Reds')
plt.title('Distribution of Hotel Types')
plt.show()

# %% [markdown]
# <div style="
#     background-color: #e8f5e9;
#     border: 1px solid #81c784;
#     padding: 15px;
#     margin: 10px 0;
#     width: 100%;
#     box-sizing: border-box;
# ">
# <p style="
#     color: #1b5e20;
#     font-family: Arial;
#     font-size: 17px;
#     margin: 0;
# ">
# 💡 <strong>Insight:</strong>The analysis of assigned room types across both City Hotel and Resort Hotel reveals a similar pattern, with Room Type A being the most frequently assigned, followed by Room Type D. This consistent preference across both hotel categories suggests that these room types are either the most available or align well with customer demand and preferences. Their high assignment frequency indicates that they likely represent the standard and most popular accommodation choices offered by both hotels.
# </p>
# </div>

# %% [markdown]
# <div style="
#     background: linear-gradient(135deg, #e3f2fd, #b2dfdb);
#     border-left: 4px solid #00796b;
#     border-radius: 12px;
#     padding: 15px 20px;
#     margin: 15px 0;
#     box-shadow: 0px 4px 8px rgba(0,0,0,0.15);
# ">
#
# <p style="
#     color: #1a237e;
#     font-size: 18px;
#     font-family: Arial;
#     margin: 0;
# ">
# <b>3. Which customer type has more tendancy to cancel booking❓
# </p>
#
# </div>

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x="CUSTOMER_TYPE", hue='IS_CANCELED', data=df_cleaned_data) 
plt.title("Booking Cancellation by Customer Type")
plt.xlabel("Customer Type")
plt.ylabel("Number of Bookings")
plt.legend(title='Cancellation Status', labels=['Not Canceled', 'Canceled'])
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="
#     background-color: #e8f5e9;
#     border: 1px solid #81c784;
#     padding: 15px;
#     margin: 10px 0;
#     width: 100%;
#     box-sizing: border-box;
# ">
# <p style="
#     color: #1b5e20;
#     font-family: Arial;
#     font-size: 17px;
#     margin: 0;
# ">
# 💡 <strong>Insight:</strong> The Transient customer segment exhibits the highest number of booking cancellations compared to all other customer types. Despite also accounting for the largest share of bookings, nearly 40% of reservations made by Transient guests are cancelled, indicating a significantly higher cancellation tendency within this group.
# </p>
# </div>

# %% [markdown]
# <div style="
#     background: linear-gradient(135deg, #e3f2fd, #b2dfdb);
#     border-left: 4px solid #00796b;
#     border-radius: 12px;
#     padding: 15px 20px;
#     margin: 15px 0;
#     box-shadow: 0px 4px 8px rgba(0,0,0,0.15);
# ">
#
# <p style="
#     color: #1a237e;
#     font-size: 18px;
#     font-family: Arial;
#     margin: 0;
# ">
# <b>4. How does the distribution of booking channels vary across market segments❓
# </p>
#
# </div>

# %%
fig = px.sunburst(
    df_cleaned_data,
    path=['MARKET_SEGMENT', 'DISTRIBUTION_CHANNEL'],
    title='Market Segment and Distribution Channel Distribution'
)
fig.update_layout(
    width=1000,
    height=800
)
fig.show()

# %% [markdown]
# <div style="
#     background-color: #e8f5e9;
#     border: 1px solid #81c784;
#     padding: 15px;
#     margin: 10px 0;
#     width: 100%;
#     box-sizing: border-box;
# ">
# <p style="
#     color: #1b5e20;
#     font-family: Arial;
#     font-size: 17px;
#     margin: 0;
# ">
# 💡 <strong>Insight:</strong> The Sunburst chart reveals that <b>Online Travel Agencies (Online TA)</b> are the dominant source of hotel bookings, accounting for the largest share of reservations and primarily using the <b>TA/TO</b> distribution channel. Direct bookings form the second-largest segment, indicating that many customers also prefer booking directly with the hotel. In contrast, corporate and group reservations contribute a comparatively smaller share of total bookings. Overall, the hotel's booking demand relies heavily on online travel platforms and travel-agent networks.
#
# </p>
# </div>

# %% [markdown]
# <div style="
#     background: linear-gradient(135deg, #e3f2fd, #b2dfdb);
#     border-left: 4px solid #00796b;
#     border-radius: 12px;
#     padding: 15px 20px;
#     margin: 15px 0;
#     box-shadow: 0px 4px 8px rgba(0,0,0,0.15);
# ">
#
# <p style="
#     color: #1a237e;
#     font-size: 18px;
#     font-family: Arial;
#     margin: 0;
# ">
# <b>5. Which countries contribute the highest number of hotel bookings in each year❓
# </p>
#
# </div>

# %%
country_bookings = (
    df_cleaned_data.groupby(
        ['ARRIVAL_DATE_YEAR', 'COUNTRY']
    )
    .size()
    .reset_index(name='BOOKINGS')
)

fig = px.choropleth(
    country_bookings,
    locations='COUNTRY',
    locationmode='ISO-3',
    color='BOOKINGS',
    hover_name='COUNTRY',
    animation_frame='ARRIVAL_DATE_YEAR',
    color_continuous_scale='Viridis',
    title='Hotel Bookings by Country Over Time'
)
fig.update_layout(
    width=1000,
    height=800
)

fig.show()

# %% [markdown]
# <div style="
#     background-color: #e8f5e9;
#     border: 1px solid #81c784;
#     padding: 15px;
#     margin: 10px 0;
#     width: 100%;
#     box-sizing: border-box;
# ">
# <p style="
#     color: #1b5e20;
#     font-family: Arial;
#     font-size: 17px;
#     margin: 0;
# ">
# 💡 <strong>Insight:</strong> Across all observed years, Portugal (PRT) remained the dominant source of hotel guests, contributing significantly more bookings than any other country. This suggests that the hotels rely heavily on domestic tourism and local travelers. While international visitors contribute to overall demand, the Portuguese market appears to provide a stable and consistent customer base, making it a crucial segment for sustaining hotel occupancy and revenue throughout the years.
# </p>
# </div>

# %% [markdown]
# <h3 style="color:darkblue; font-family:Georgia; text-decoration: underline; font-weight:bold">
# 3️⃣ MULTIVARIATE ANALYSIS
# </h3>

# %% [markdown]
# <div style="
#     background: linear-gradient(135deg, #e3f2fd, #b2dfdb);
#     border-left: 4px solid #00796b;
#     border-radius: 12px;
#     padding: 15px 20px;
#     margin: 15px 0;
#     box-shadow: 0px 4px 8px rgba(0,0,0,0.15);
# ">
#
# <p style="
#     color: #1a237e;
#     font-size: 18px;
#     font-family: Arial;
#     margin: 0;
# ">
# <b>1. What relationships exist between room rates (ADR), booking behavior, stay duration, and customer characteristics❓
# </p>
#
# </div>

# %%
corr = df_cleaned_data[['ADR','LEAD_TIME','STAYS_IN_WEEKEND_NIGHTS','STAYS_IN_WEEK_NIGHTS','ADULTS','TOTAL_OF_SPECIAL_REQUESTS']].corr()

# %%
sns.heatmap(corr,annot=True,cmap='cividis')
# Out:
# <Axes: >

# %% [markdown]
# <div style="
#     background-color: #e8f5e9;
#     border: 1px solid #81c784;
#     padding: 15px;
#     margin: 10px 0;
#     width: 100%;
#     box-sizing: border-box;
# ">
# <p style="
#     color: #1b5e20;
#     font-family: Arial;
#     font-size: 17px;
#     margin: 0;
# ">
# 💡 <strong>Insight:</strong> The strongest relationship is observed between weekend-night stays and weekday-night stays (r = 0.55), indicating that guests who stay during weekends often extend their stay into weekdays. ADR has almost no relationship with the length of stay, indicating that room rates are influenced more by factors such as hotel type, season, or room category than by the number of nights booked. Additionally, ADR shows a moderate positive correlation with the number of adults (r = 0.34), suggesting that larger groups tend to generate higher room revenue. Most other variables exhibit weak correlations, implying that hotel pricing and booking behavior are influenced by multiple factors rather than a single dominant variable.
# </p>
# </div>

# %% [markdown]
# <div style="
#     background: linear-gradient(135deg, #e3f2fd, #b2dfdb);
#     border-left: 4px solid #00796b;
#     border-radius: 12px;
#     padding: 15px 20px;
#     margin: 15px 0;
#     box-shadow: 0px 4px 8px rgba(0,0,0,0.15);
# ">
#
# <p style="
#     color: #1a237e;
#     font-size: 18px;
#     font-family: Arial;
#     margin: 0;
# ">
# <b>2. How does the length of stay influence the Average Daily Rate (ADR) across different hotel types❓
# </p>
#
# </div>

# %%
df_cleaned_data['TOTAL_DAYS_STAYED'] = (df_cleaned_data['STAYS_IN_WEEKEND_NIGHTS'] +df_cleaned_data['STAYS_IN_WEEK_NIGHTS'])

df_plot = df_cleaned_data[(df_cleaned_data['TOTAL_DAYS_STAYED'] > 0) &(df_cleaned_data['ADR'] > 0)]

plt.figure(figsize=(14,8))
sns.scatterplot(data=df_plot,x='TOTAL_DAYS_STAYED',y='ADR',hue='HOTEL',alpha=0.6)
plt.title('Effect of Stay Duration and Hotel Type on ADR')
plt.xlabel('Total Days Stayed')
plt.ylabel('ADR')
plt.show()

# %% [markdown]
# <div style="
#     background-color: #e8f5e9;
#     border: 1px solid #81c784;
#     padding: 15px;
#     margin: 10px 0;
#     width: 100%;
#     box-sizing: border-box;
# ">
# <p style="
#     color: #1b5e20;
#     font-family: Arial;
#     font-size: 17px;
#     margin: 0;
# ">
# 💡 <strong>Insight:</strong> The scatter plot indicates that ADR does not increase with longer stays in either City Hotels or Resort Hotels. Instead, a declining trend is observed, highlighting an inverse relationship between stay duration and room rates. This may reflect pricing strategies such as extended-stay discounts and negotiated rates offered to long-term guests.
# </p>
# </div>

# %% [markdown]
# <div style="
#     background: linear-gradient(135deg, #e3f2fd, #b2dfdb);
#     border-left: 4px solid #00796b;
#     border-radius: 12px;
#     padding: 15px 20px;
#     margin: 15px 0;
#     box-shadow: 0px 4px 8px rgba(0,0,0,0.15);
# ">
#
# <p style="
#     color: #1a237e;
#     font-size: 18px;
#     font-family: Arial;
#     margin: 0;
# ">
# <b>3. How do hotel booking volumes vary across different months for City Hotels and Resort Hotels❓
# </p>
#
# </div>

# %%
booking_month = df_cleaned_data.groupby(
    ['ARRIVAL_DATE_YEAR','ARRIVAL_DATE_MONTH','HOTEL']
).size().reset_index(name='BOOKINGS')

fig = px.bar(
    booking_month,
    x='HOTEL',
    y='BOOKINGS',
    color='HOTEL',
    animation_frame='ARRIVAL_DATE_MONTH',
    title='Hotel Bookings by Month'
)

fig.show()

# %% [markdown]
# <div style="
#     background-color: #e8f5e9;
#     border: 1px solid #81c784;
#     padding: 15px;
#     margin: 10px 0;
#     width: 100%;
#     box-sizing: border-box;
# ">
# <p style="
#     color: #1b5e20;
#     font-family: Arial;
#     font-size: 17px;
#     margin: 0;
# ">
# 💡 <strong>Insight:</strong> Bookings reach their highest levels during July and August for both hotels, indicating strong seasonal demand. City Hotels attain their maximum bookings in August, whereas Resort Hotels experience their peak demand in July..
# </p>
# </div>

# %% [markdown]
# <div style="
#     background: linear-gradient(135deg, #e3f2fd, #b2dfdb);
#     border-left: 4px solid #00796b;
#     border-radius: 12px;
#     padding: 15px 20px;
#     margin: 15px 0;
#     box-shadow: 0px 4px 8px rgba(0,0,0,0.15);
# ">
#
# <p style="
#     color: #1a237e;
#     font-size: 18px;
#     font-family: Arial;
#     margin: 0;
# ">
# <b>4. How do booking cancellations vary across different market segments in City Hotels and Resort Hotels❓
# </p>
#
# </div>

# %%
cancel_data = pd.crosstab(
    [df_cleaned_data['MARKET_SEGMENT'],
     df_cleaned_data['HOTEL']],
    df_cleaned_data['IS_CANCELED']
)

cancel_data
# Out:
# IS_CANCELED                     No    Yes
# MARKET_SEGMENT HOTEL
# Aviation       City Hotel      182     45
# Complementary  City Hotel      453     57
#                Resort Hotel    157     31
# Corporate      City Hotel     1942    255
#                Resort Hotel   1727    246
# Direct         City Hotel     4472    858
#                Resort Hotel   5048    705
# Groups         City Hotel     1501    534
#                Resort Hotel   1474    384
# Offline TA/TO  City Hotel     5531   1009
#                Resort Hotel   5518    737
# Online TA      City Hotel    21902  12113
#                Resort Hotel  10239   4789
# Undefined      City Hotel        0      2

# %% [markdown]
# <div style="
#     background-color: #e8f5e9;
#     border: 1px solid #81c784;
#     padding: 15px;
#     margin: 10px 0;
#     width: 100%;
#     box-sizing: border-box;
# ">
# <p style="
#     color: #1b5e20;
#     font-family: Arial;
#     font-size: 17px;
#     margin: 0;
# ">
# 💡 <strong>Insight:</strong> The <b>Online TA (Online Travel Agency)</b> segment generated the highest number of bookings and also recorded the largest number of cancellations across both hotel types. City Hotels received <b>21,902 successful bookings</b> and <b>12,113 cancellations</b> from Online TA customers, while Resort Hotels recorded <b>10,239 successful bookings</b> and <b>4,789 cancellations</b>. In contrast, bookings from <b>Direct</b> and <b>Corporate</b> segments showed significantly lower cancellation volumes. Overall, the results suggest that customers booking through online travel agencies are more likely to cancel reservations, making Online TA the most influential segment in both hotel demand and cancellation behavior.
# </p>
# </div>

# %% [markdown]
# <div style="
#     background: linear-gradient(135deg, #d9f3ff, #b2dfdb);
#     border: 4px solid #008080;
#     border-radius: 10px;
#     padding: 5px;
#     margin: 15px 0;
#     box-shadow: 0px 6px 15px rgba(0,0,0,0.2);
#     display: flex;
#     justify-content: space-between;
#     align-items: center;
# ">
#
# <div style="flex: 4;">
#     <h2 style="color:darkblue; font-family:Georgia; font-weight:bold;text-decoration: underline">
# 10.CONCLUSION
# </h2>

# %% [markdown]
# <div style="
# background:#e3f2fd;
# border-left:5px solid #1565c0;
# padding:12px;
# margin:10px 0;
# font-size: 17px;
# ">
#
# <b>🎯 This exploratory data analysis uncovered key patterns in hotel booking behavior, customer preferences, booking channels, cancellations, and revenue-related factors, providing valuable insights into overall hotel performance.
#
# </div>

# %% [markdown]
# 1.City Hotels recorded a higher average ADR than Resort Hotels.
#
# 2.Online Travel Agencies (Online TA) generated the highest number of bookings and cancellations.
#
# 3.Portugal was the largest source of guests across all years.
#
# 4.Repeat guests showed lower cancellation tendencies.
#
# 5.Customers with previous cancellations were more likely to cancel again.
#
# 6.Direct and Corporate bookings were generally more stable than Online TA bookings.
#
# 7.Most ADR = 0 bookings were successful check-outs rather than cancellations.
#
# 8.Agent ID 9 contributed the highest number of bookings.
#
# 9.Hotel demand was strongly influenced by seasonality and booking channels.

# %% [markdown]
# <div style="
#     background: linear-gradient(135deg, #d9f3ff, #b2dfdb);
#     border: 4px solid #008080;
#     border-radius: 10px;
#     padding: 5px;
#     margin: 15px 0;
#     box-shadow: 0px 6px 15px rgba(0,0,0,0.2);
#     display: flex;
#     justify-content: space-between;
#     align-items: center;
# ">
#
# <div style="flex: 4;">
#     <h2 style="color:darkblue; font-family:Georgia; font-weight:bold;text-decoration: underline">
# 11.BUSINESS RECOMMENDATIONS
# </h2>

# %% [markdown]
# <div style="
# background:#f1f8e9;
# border-left:5px solid #558b2f;
# padding:12px;
# margin:10px 0;
# font-size: 17px;
# ">
#
# <b>💡 Based on the findings obtained from the analysis, the following recommendations may help improve booking performance, customer retention, and overall hotel revenue.
#
# </div>

# %% [markdown]
# 1.Strengthen relationships with high-performing travel agents because they contribute a significant share of bookings.
#
# 2.Implement targeted retention strategies for repeat guests since they are less likely to cancel.
#
# 3.Monitor bookings from customers with a history of cancellations and consider stricter cancellation policies for high-risk reservations.
#
# 4.Increase direct booking incentives to reduce dependency on Online Travel Agencies and lower commission costs.
#
# 5.Focus marketing campaigns on key source markets such as Portugal and other top contributing countries.
#
# 6.Customers making special requests may have higher service expectations. Hotels can use this information to improve guest experiences and increase customer satisfaction.
#
# 7.Monthly and seasonal booking trends can be used to adjust room prices dynamically during high-demand periods to maximize revenue.

# %% [markdown]
# <div style="
#     background: linear-gradient(135deg, #d9f3ff, #b2dfdb);
#     border: 4px solid #008080;
#     border-radius: 10px;
#     padding: 5px;
#     margin: 15px 0;
#     box-shadow: 0px 6px 15px rgba(0,0,0,0.2);
#     display: flex;
#     justify-content: space-between;
#     align-items: center;
# ">
#
# <div style="flex: 4;">
#     <h2 style="color:darkblue; font-family:Georgia; font-weight:bold;text-decoration: underline">
# 12.LIMITATIONS OF THE ANALYSIS
# </h2>

# %% [markdown]
# <div style="
# background:#ffebee;
# border-left:5px solid #c62828;
# padding:12px;
# margin:10px 0;
# font-size: 17px;
# ">
#
# <b>⚠️ While the analysis provides meaningful insights, certain limitations within the dataset and scope of the study should be considered when interpreting the results.
#
# </div>

# %% [markdown]
# 1.The dataset represents historical booking data only.
#
# 2.Customer satisfaction information is not available.
#
# 3.Revenue analysis is limited to ADR and does not include total hotel income.
#
# 4.External factors such as economic conditions and weather were not considered.

# %% [markdown]
# <div style="
#     background: linear-gradient(135deg, #d9f3ff, #b2dfdb);
#     border: 4px solid #008080;
#     border-radius: 10px;
#     padding: 5px;
#     margin: 15px 0;
#     box-shadow: 0px 6px 15px rgba(0,0,0,0.2);
#     display: flex;
#     justify-content: space-between;
#     align-items: center;
# ">
#
# <div style="flex: 4;">
#     <h2 style="color:darkblue; font-family:Georgia; font-weight:bold;text-decoration: underline">
# 13.FUTURE SCOPE
# </h2>

# %% [markdown]
# <div style="
# background:#ede7f6;
# border-left:5px solid #6a1b9a;
# padding:12px;
# margin:10px 0;
# font-size: 17px;
# ">
#
# <b>🚀 Future work can extend this analysis by incorporating predictive modeling, advanced customer segmentation, and interactive dashboards for deeper business insights.
#
# </div>

# %% [markdown]
# 1.Build a machine learning model to predict booking cancellations.
#
# 2.Forecast future hotel demand using time-series analysis.
#
# 3.Develop an interactive hotel booking dashboard using Plotly Dash or Power BI.
#
# 4.Perform customer segmentation to identify high-value guest groups.
#
# 5.Analyze pricing strategies to maximize occupancy and revenue.
#
# 6.Incorporate weather conditions, holidays, tourism trends, and economic indicators to improve booking forecasts and business decisions.
#
# 7.Build a recommendation engine that suggests suitable room types, packages, or offers based on customer preferences and booking history.
